# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def heat_generation(I, R, t):
    p = (I**2)*R
    Q = p*t
    return Q

def specifc_heat():
    return (rho/V)*c

# %%
print(heat_generation(24, 2.2, 5*60), "J")
# Out:
# 380160.0 J

# %%
time = np.linspace(1, 1000, 1000)
heat = heat_generation(24, 2.2, time)
plt.figure(figsize=(12,8))
plt.plot(time/60, heat)
plt.xlabel("Time [min]", size=12)
plt.ylabel("Heat [J]", size=12)
plt.title("Time vs. Heat", size=18)
plt.grid()
plt.show()

# %%
# Out:
# 0.024041470515667407
